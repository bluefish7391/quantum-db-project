# %%
import qiskit

# %%
qiskit.__version__
# Out:
# '2.2.3'

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService(
    channel="ibm_quantum_platform",
    token="PGyEO4i0MGHysqjRK3CXLR5mTDg-B5bYyubGZMZ92x7n",
    instance="crn:v1:bluemix:public:quantum-computing:us-east:a/39a5c0fd3fbb4639bf3f5c7610833cc2:dc2bd6f4-9a13-44aa-a708-56c8899cc759::"
)
# Out:
# qiskit_runtime_service._discover_account:WARNING:2025-12-29 19:24:01,485: Loading account with the given token. A saved account will not be used.

# %%
QiskitRuntimeService.save_account(
    channel="ibm_quantum_platform",
    token="PGyEO4i0MGHysqjRK3CXLR5mTDg-B5bYyubGZMZ92x7n",
    instance="crn:v1:bluemix:public:quantum-computing:us-east:a/39a5c0fd3fbb4639bf3f5c7610833cc2:dc2bd6f4-9a13-44aa-a708-56c8899cc759::"
)

# %%
service.backends()
# Out:
# [<IBMBackend('ibm_fez')>,
#  <IBMBackend('ibm_torino')>,
#  <IBMBackend('ibm_marrakesh')>]

# %%
backend = service.backend("ibm_fez")
print(backend.num_qubits)
# Out:
# 156
